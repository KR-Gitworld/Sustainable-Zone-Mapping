# %% [markdown]
# <a href="https://colab.research.google.com/github/KR-Gitworld/Sustainable-Zone-Mapping/blob/main/Sustainable_zonemapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/sustainable_zone_mapping (1).csv")
df.head()
# Out:
#    Zone_ID   Latitude   Longitude Land_Use_Type  Pollution_Level  \
# 0        1  34.749080 -118.222301   Residential            50.60
# 1        2  35.901429 -117.687149   Residential            46.17
# 2        3  35.463988 -117.190581        Forest            16.84
# 3        4  35.197317 -117.401663   Residential            26.34
# 4        5  34.312037 -117.290158   Residential            52.12
#
#    Green_Cover_Percentage  Water_Availability_Index  Population_Density  \
# 0                   24.81                      0.00                7921
# 1                   26.59                     27.30                7563
# 2                   74.28                     70.55                 301
# 3                   30.77                      5.68                8743
# 4                   24.06                     30.13                6191
#
#    Avg_Temperature Sustainability_Class
# 0            28.56             Critical
# 1            20.92             Critical
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Sustainability_Class'] = label_encoder.fit_transform(df['Sustainability_Class'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Land_Use_Type'] = label_encoder.fit_transform(df['Land_Use_Type'])

# %%
x = df.drop(columns=["Sustainability_Class"])
x
# Out:
#      Zone_ID   Latitude   Longitude  Land_Use_Type  Pollution_Level  \
# 0          1  34.749080 -118.222301              4            50.60
# 1          2  35.901429 -117.687149              4            46.17
# 2          3  35.463988 -117.190581              2            16.84
# 3          4  35.197317 -117.401663              4            26.34
# 4          5  34.312037 -117.290158              4            52.12
# ..       ...        ...         ...            ...              ...
# 995      996  34.183164 -117.514567              2            26.28
# 996      997  35.834627 -117.065078              4            37.16
# 997      998  34.273637 -118.396563              1            65.91
# 998      999  35.900475 -118.414418              4            46.79
# 999     1000  34.892012 -118.076719              2             8.63
#
#      Green_Cover_Percentage  Water_Availability_Index  Population_Density  \
# 0                     24.81                      0.00                7921
# ...

# %%
y = df["Sustainability_Class"]
y
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 995    1
# 996    0
# 997    0
# 998    0
# 999    1
# Name: Sustainability_Class, Length: 1000, dtype: int64

# %%
df.head()
# Out:
#    Zone_ID   Latitude   Longitude  Land_Use_Type  Pollution_Level  \
# 0        1  34.749080 -118.222301              4            50.60
# 1        2  35.901429 -117.687149              4            46.17
# 2        3  35.463988 -117.190581              2            16.84
# 3        4  35.197317 -117.401663              4            26.34
# 4        5  34.312037 -117.290158              4            52.12
#
#    Green_Cover_Percentage  Water_Availability_Index  Population_Density  \
# 0                   24.81                      0.00                7921
# 1                   26.59                     27.30                7563
# 2                   74.28                     70.55                 301
# 3                   30.77                      5.68                8743
# 4                   24.06                     30.13                6191
#
#    Avg_Temperature  Sustainability_Class
# 0            28.56                     0
# 1            20.92                     0
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(ytest, ypred)

class_report = classification_report(ytest, ypred)

# Print results
print("Model Accuracy:", accuracy)

print("Classification Report:\n", class_report)
# Out:
# Model Accuracy: 0.855
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89       124
#            1       0.95      0.97      0.96        37
#            2       0.71      0.51      0.60        39
#
#     accuracy                           0.85       200
#    macro avg       0.84      0.80      0.82       200
# weighted avg       0.85      0.85      0.85       200

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(xtrain,ytrain)
ypred = knn.predict(xtest)
from sklearn.metrics import classification_report
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.89       124
#            1       0.92      0.97      0.95        37
#            2       0.69      0.69      0.69        39
#
#     accuracy                           0.86       200
#    macro avg       0.84      0.85      0.84       200
# weighted avg       0.86      0.86      0.86       200

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(xtrain,ytrain)
ypred = dt.predict(xtest)
from sklearn.metrics import classification_report
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       124
#            1       1.00      0.97      0.99        37
#            2       1.00      0.95      0.97        39
#
#     accuracy                           0.98       200
#    macro avg       0.99      0.97      0.98       200
# weighted avg       0.99      0.98      0.98       200
